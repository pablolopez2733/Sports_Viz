# %% [markdown]
# ## Import Data

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ArrowheadAnalytics/next-gen-scrapy-2.0/master/pass_and_game_data.csv', low_memory=False)
#There's an additional index row we don't need, so I am getting rid of it here
df = df.iloc[0:,1:]

# %%
#Drop the games that weren't able to be scraped
df.dropna(inplace=True)
#Explore the data a bit
df.head(3)
# Out:
#       game_id           name pass_type team week  x_coord  y_coord type  \
# 0  2017091004  Carson Palmer  COMPLETE  ARI    1    -23.5     14.6  reg
# 1  2017091004  Carson Palmer  COMPLETE  ARI    1      2.8      9.3  reg
# 2  2017091004  Carson Palmer  COMPLETE  ARI    1     18.6     -1.1  reg
#
#   home_team away_team  season  \
# 0       DET       ARI    2017
# 1       DET       ARI    2017
# 2       DET       ARI    2017
#
#                                             game_url  home_score  away_score
# 0  http://www.nfl.com/liveupdate/game-center/2017...          35          23
# 1  http://www.nfl.com/liveupdate/game-center/2017...          35          23
# 2  http://www.nfl.com/liveupdate/game-center/2017...          35          23

# %%
df.describe()
# Out:
#             game_id       x_coord       y_coord        season    home_score  \
# count  4.383900e+04  43839.000000  43839.000000  43839.000000  43839.000000
# mean   2.018206e+09      0.401437      8.352120   2018.069527     23.654600
# std    8.202842e+05     15.229154      9.998542      0.825039     10.318057
# min    2.017091e+09    -28.300000    -10.400000   2017.000000      0.000000
# 25%    2.017122e+09    -12.300000      1.900000   2017.000000     17.000000
# 50%    2.018112e+09      0.900000      5.700000   2018.000000     24.000000
# 75%    2.019101e+09     12.900000     13.100000   2019.000000     31.000000
# max    2.019123e+09     28.300000     62.100000   2019.000000     57.000000
#
#          away_score
# count  43839.000000
# mean      22.306827
# std       10.243724
# min        0.000000
# 25%       16.000000
# 50%       23.000000
# 75%       28.000000
# max       59.000000

# %% [markdown]
# ## Plots

# %%
#Let's visualize the distribution of the coordinates
fig = sns.distplot(df.x_coord, kde=False)
plt.show()

# %%
#Now the x coordinate
fig = sns.distplot(df.y_coord, kde=False)
plt.show()

# %%
fig = sns.jointplot(x='x_coord', y='y_coord', data=df)
plt.show()

# %% [markdown]
# ## Hex

# %%
fig = sns.jointplot(x='x_coord', y='y_coord', data=df, kind='hex', color='red')
plt.show()

# %%
#Smoother
fig = sns.jointplot(x='x_coord', y='y_coord', data=df, kind='kde', cmap='Reds', color='red')
plt.show()

# %% [markdown]
# ## Comparing Carr and Mahomes

# %%
#prepare our two plots - no reason to separate out our axes here as we want to compare these two players on an equal scale so we set sharex and sharey to true
fig, ax =plt.subplots(1,2, sharex=True, sharey=True)

#First, we'll partition the data to the player we are looking for
qb_name = 'Mahomes' #I'm being intentional vague here and not listing the full player name, because many player names listed on Next Gen Stats are different than you're likely accustomed to. So, I've found this method easire to ensure I get the player data
qb = df.loc[(df['name'].str.contains(qb_name))]
#Assign this plot to the first (0-index) axis. Not going to use the univariate distributions on the axes for these plots as they don't work well as subplots
sns.kdeplot(qb.x_coord, qb.y_coord, ax=ax[0], cmap='Reds')

#Let's get player 2
qb_name = 'Carr'
qb = df.loc[(df['name'].str.contains(qb_name))]
#Second plot
sns.kdeplot(qb.x_coord, qb.y_coord, ax=ax[1], cmap='Reds')
plt.show()

# %%
#Layering two plotting styles here to get a big, clean, but dark background look
plt.style.use('seaborn-poster')
plt.style.use('dark_background')

#Set up our subplots
fig, (ax1, ax2) =plt.subplots(1,2)


qb_name = 'Mahomes'
qb = df.loc[(df['name'].str.contains(qb_name))]

#What we've added here is shading for the densities, but leaving the lowest density area unshaded.
#I've also added the *n_level* parameter, which allows us to choose how many levels we want to have in our contour. The higher the number here, the smoother the plot will look.
sns.kdeplot(qb.x_coord, qb.y_coord, ax=ax1, cmap='gist_heat', shade=True, shade_lowest=False, n_levels=10)

#Set title, remove ticks and labels
ax1.set_title(qb_name)
ax1.set_xlabel('')
ax1.set_xticks([])
ax1.set_yticks([])
ax1.set_ylabel('')

#Remove any part of the plot that is out of bounds
ax1.set_xlim(-53.3333/2, 53.3333/2)
ax1.set_ylim(-15,60)
#This makes our scales (x and y) equal (1 pixel in the x direction is the same 'distance' in coordinates as 1 pixel in the y direction)




#Plot all of the field markings (line of scrimmage, hash marks, etc.)
for j in range(-15,60-1,1):
    ax1.annotate('--', (-3.1,j-0.5),
                 ha='center',fontsize =10)
    ax1.annotate('--', (3.1,j-0.5),
                 ha='center',fontsize =10)
    
for i in range(-10,60,5):
    ax1.axhline(i,c='w',ls='-',alpha=0.7, lw=1.5)
    
for i in range(-10,60,10):
    ax1.axhline(i,c='w',ls='-',alpha=1, lw=1.5)
    
for i in range(10,60-1,10):
    ax1.annotate(str(i), (-12.88,i-1.15),
            ha='center',fontsize =15,
                rotation=270)
    
    ax1.annotate(str(i), (12.88,i-0.65),
            ha='center',fontsize =15,
                rotation=90)


#Now we just repeat for player 2.
qb_name = 'Carr'
qb = df.loc[(df['name'].str.contains(qb_name))]
#Second plot
sns.kdeplot(qb.x_coord, qb.y_coord, ax=ax2, cmap='gist_heat', shade=True, shade_lowest=False, n_levels=10)

ax2.set_title(qb_name)
ax2.set_xlabel('')
ax2.set_ylabel('')
ax2.set_xticks([])
ax2.set_yticks([])
ax2.set_xlim(-53.3333/2, 53.3333/2)
ax2.set_ylim(-15,60)
for j in range(-15,60,1):
    ax2.annotate('--', (-3.1,j-0.5),
                 ha='center',fontsize =10)
    ax2.annotate('--', (3.1,j-0.5),
                 ha='center',fontsize =10)
    
for i in range(-10,60,5):
    ax2.axhline(i,c='w',ls='-',alpha=0.7, lw=1.5)
    
for i in range(-10,60,10):
    ax2.axhline(i,c='w',ls='-',alpha=1, lw=1.5)
    
for i in range(10,60-1,10):
    ax2.annotate(str(i), (-12.88,i-1.15),
            ha='center',fontsize =15,
                rotation=270)
    
    ax2.annotate(str(i), (12.88,i-0.65),
            ha='center',fontsize =15,
                rotation=90)

plt.show()

# %% [markdown]
# ## Brissett vs Luck

# %%
#Layering two plotting styles here to get a big, clean, but dark background look
plt.style.use('seaborn-poster')
plt.style.use('dark_background')

#Set up our subplots
fig, (ax1, ax2) =plt.subplots(1,2)


qb_name = 'Andrew Luck'
qb = df.loc[(df['name'].str.contains(qb_name))]

#What we've added here is shading for the densities, but leaving the lowest density area unshaded.
#I've also added the *n_level* parameter, which allows us to choose how many levels we want to have in our contour. The higher the number here, the smoother the plot will look.
sns.kdeplot(qb.x_coord, qb.y_coord, ax=ax1, cmap='gist_heat', shade=True, shade_lowest=False, n_levels=10)

#Set title, remove ticks and labels
ax1.set_title(qb_name)
ax1.set_xlabel('')
ax1.set_xticks([])
ax1.set_yticks([])
ax1.set_ylabel('')

#Remove any part of the plot that is out of bounds
ax1.set_xlim(-53.3333/2, 53.3333/2)
ax1.set_ylim(-15,60)
#This makes our scales (x and y) equal (1 pixel in the x direction is the same 'distance' in coordinates as 1 pixel in the y direction)




#Plot all of the field markings (line of scrimmage, hash marks, etc.)
for j in range(-15,60-1,1):
    ax1.annotate('--', (-3.1,j-0.5),
                 ha='center',fontsize =10)
    ax1.annotate('--', (3.1,j-0.5),
                 ha='center',fontsize =10)
    
for i in range(-10,60,5):
    ax1.axhline(i,c='w',ls='-',alpha=0.7, lw=1.5)
    
for i in range(-10,60,10):
    ax1.axhline(i,c='w',ls='-',alpha=1, lw=1.5)
    
for i in range(10,60-1,10):
    ax1.annotate(str(i), (-12.88,i-1.15),
            ha='center',fontsize =15,
                rotation=270)
    
    ax1.annotate(str(i), (12.88,i-0.65),
            ha='center',fontsize =15,
                rotation=90)


#Now we just repeat for player 2.
qb_name = 'Jacoby Brissett'
qb = df.loc[(df['name'].str.contains(qb_name))]
#Second plot
sns.kdeplot(qb.x_coord, qb.y_coord, ax=ax2, cmap='gist_heat', shade=True, shade_lowest=False, n_levels=10)

ax2.set_title(qb_name)
ax2.set_xlabel('')
ax2.set_ylabel('')
ax2.set_xticks([])
ax2.set_yticks([])
ax2.set_xlim(-53.3333/2, 53.3333/2)
ax2.set_ylim(-15,60)
for j in range(-15,60,1):
    ax2.annotate('--', (-3.1,j-0.5),
                 ha='center',fontsize =10)
    ax2.annotate('--', (3.1,j-0.5),
                 ha='center',fontsize =10)
    
for i in range(-10,60,5):
    ax2.axhline(i,c='w',ls='-',alpha=0.7, lw=1.5)
    
for i in range(-10,60,10):
    ax2.axhline(i,c='w',ls='-',alpha=1, lw=1.5)
    
for i in range(10,60-1,10):
    ax2.annotate(str(i), (-12.88,i-1.15),
            ha='center',fontsize =15,
                rotation=270)
    
    ax2.annotate(str(i), (12.88,i-0.65),
            ha='center',fontsize =15,
                rotation=90)

plt.show()

# %% [markdown]
# Now let´s see in close games

# %%
df["Differential"] = abs(df["home_score"]-df["away_score"])
df.head()
# Out:
#       game_id           name pass_type team week  x_coord  y_coord type  \
# 0  2017091004  Carson Palmer  COMPLETE  ARI    1    -23.5     14.6  reg
# 1  2017091004  Carson Palmer  COMPLETE  ARI    1      2.8      9.3  reg
# 2  2017091004  Carson Palmer  COMPLETE  ARI    1     18.6     -1.1  reg
# 3  2017091004  Carson Palmer  COMPLETE  ARI    1     -8.4      8.3  reg
# 4  2017091004  Carson Palmer  COMPLETE  ARI    1    -15.5      8.0  reg
#
#   home_team away_team  season  \
# 0       DET       ARI    2017
# 1       DET       ARI    2017
# 2       DET       ARI    2017
# 3       DET       ARI    2017
# 4       DET       ARI    2017
#
#                                             game_url  home_score  away_score  \
# 0  http://www.nfl.com/liveupdate/game-center/2017...          35          23
# 1  http://www.nfl.com/liveupdate/game-center/2017...          35          23
# 2  http://www.nfl.com/liveupdate/game-center/2017...          35          23
# 3  http://www.nfl.com/liveupdate/game-center/2017...          35          23
# 4  http://www.nfl.com/liveupdate/game-center/2017...          35          23
#
#    Differential
# 0            12
# 1            12
# 2            12
# 3            12
# 4            12

# %%
#Luck close games
luck = df.loc[(df['name']==('Andrew Luck')) & (df['Differential']<=7)]
#Brissetts close games:
brissett = df.loc[(df['name']==('Jacoby Brissett')) & (df['Differential']<=7)]

# %%
luck_comp = luck[luck["pass_type"]=='COMPLETE'].shape[0]
luck_totals = luck.shape[0]
luck_perc = round(luck_comp*100/luck_totals,2)

bris_comp = brissett[brissett["pass_type"]=='COMPLETE'].shape[0]
bris_totals = brissett.shape[0]
brissett_perc = round(bris_comp*100/bris_totals,2)


print("Luck completion % in close games: ",luck_perc,"%")
print("Brissett completion % in close games: ",brissett_perc,"%")
# Out:
# Luck completion % in close games:  63.58 %
# Brissett completion % in close games:  59.59 %

# %% [markdown]
# ## Plots

# %%
#Now we just repeat for player 2.
#Layering two plotting styles here to get a big, clean, but dark background look
plt.style.use('seaborn-poster')
plt.style.use('dark_background')

#Set up our subplots
fig, (ax1, ax2) =plt.subplots(1,2)


qb = df.loc[(df['name']==('Jacoby Brissett')) & (df['Differential']<=7)]

#What we've added here is shading for the densities, but leaving the lowest density area unshaded.
#I've also added the *n_level* parameter, which allows us to choose how many levels we want to have in our contour. The higher the number here, the smoother the plot will look.
sns.kdeplot(qb.x_coord, qb.y_coord, ax=ax1, cmap='gist_heat', shade=True, shade_lowest=False, n_levels=10)

#Set title, remove ticks and labels
ax1.set_title("Jacoby Brissett")
ax1.annotate( "Completion %: "+ str(brissett_perc),(.5, -15) ,ha='center',fontsize=15)
ax1.set_xlabel('')
ax1.set_xticks([])
ax1.set_yticks([])
ax1.set_ylabel('')

#Remove any part of the plot that is out of bounds
ax1.set_xlim(-53.3333/2, 53.3333/2)
ax1.set_ylim(-15,60)
#This makes our scales (x and y) equal (1 pixel in the x direction is the same 'distance' in coordinates as 1 pixel in the y direction)




#Plot all of the field markings (line of scrimmage, hash marks, etc.)
for j in range(-15,60-1,1):
    ax1.annotate('--', (-3.1,j-0.5),
                 ha='center',fontsize =10)
    ax1.annotate('--', (3.1,j-0.5),
                 ha='center',fontsize =10)
    
for i in range(-10,60,5):
    ax1.axhline(i,c='w',ls='-',alpha=0.7, lw=1.5)
    
for i in range(-10,60,10):
    ax1.axhline(i,c='w',ls='-',alpha=1, lw=1.5)
    
for i in range(10,60-1,10):
    ax1.annotate(str(i), (-12.88,i-1.15),
            ha='center',fontsize =15,
                rotation=270)
    
    ax1.annotate(str(i), (12.88,i-0.65),
            ha='center',fontsize =15,
                rotation=90)




qb = df.loc[(df['name']==('Andrew Luck')) & (df['Differential']<=7)]
#Second plot
sns.kdeplot(qb.x_coord, qb.y_coord, ax=ax2, cmap='gist_heat', shade=True, shade_lowest=False, n_levels=10)

ax2.set_title("Andrew Luck")
ax2.set_xlabel('')
ax2.set_ylabel('')
ax2.set_xticks([])
ax2.set_yticks([])
ax2.set_xlim(-53.3333/2, 53.3333/2)
ax2.set_ylim(-15,60)
ax2.annotate( "Completion %: "+ str(luck_perc),(.5, -15) ,ha='center',fontsize=15)
for j in range(-15,60,1):
    ax2.annotate('--', (-3.1,j-0.5),
                 ha='center',fontsize =10)
    ax2.annotate('--', (3.1,j-0.5),
                 ha='center',fontsize =10)
    
for i in range(-10,60,5):
    ax2.axhline(i,c='w',ls='-',alpha=0.7, lw=1.5)
    
for i in range(-10,60,10):
    ax2.axhline(i,c='w',ls='-',alpha=1, lw=1.5)
    
for i in range(10,60-1,10):
    ax2.annotate(str(i), (-12.88,i-1.15),
            ha='center',fontsize =15,
                rotation=270)
    
    ax2.annotate(str(i), (12.88,i-0.65),
            ha='center',fontsize =15,
                rotation=90)

plt.show()

# %% [markdown]
# ## Completions

# %%
#Now we just repeat for player 2.
#Layering two plotting styles here to get a big, clean, but dark background look
plt.style.use('seaborn-poster')
plt.style.use('dark_background')

#Set up our subplots
fig, (ax1, ax2) =plt.subplots(1,2)


qb = df.loc[(df['name']==('Jacoby Brissett')) & (df['Differential']<=7) & (df["pass_type"]=="COMPLETE")]

#What we've added here is shading for the densities, but leaving the lowest density area unshaded.
#I've also added the *n_level* parameter, which allows us to choose how many levels we want to have in our contour. The higher the number here, the smoother the plot will look.
sns.kdeplot(qb.x_coord, qb.y_coord, ax=ax1, cmap='gist_heat', shade=True, shade_lowest=False, n_levels=10)

#Set title, remove ticks and labels
ax1.set_title("Jacoby Brissett")
ax1.annotate( "Completion %: "+ str(brissett_perc),(.5, -15) ,ha='center',fontsize=15)
ax1.set_xlabel('')
ax1.set_xticks([])
ax1.set_yticks([])
ax1.set_ylabel('')

#Remove any part of the plot that is out of bounds
ax1.set_xlim(-53.3333/2, 53.3333/2)
ax1.set_ylim(-15,60)
#This makes our scales (x and y) equal (1 pixel in the x direction is the same 'distance' in coordinates as 1 pixel in the y direction)




#Plot all of the field markings (line of scrimmage, hash marks, etc.)
for j in range(-15,60-1,1):
    ax1.annotate('--', (-3.1,j-0.5),
                 ha='center',fontsize =10)
    ax1.annotate('--', (3.1,j-0.5),
                 ha='center',fontsize =10)
    
for i in range(-10,60,5):
    ax1.axhline(i,c='w',ls='-',alpha=0.7, lw=1.5)
    
for i in range(-10,60,10):
    ax1.axhline(i,c='w',ls='-',alpha=1, lw=1.5)
    
for i in range(10,60-1,10):
    ax1.annotate(str(i), (-12.88,i-1.15),
            ha='center',fontsize =15,
                rotation=270)
    
    ax1.annotate(str(i), (12.88,i-0.65),
            ha='center',fontsize =15,
                rotation=90)




qb = df.loc[(df['name']==('Andrew Luck')) & (df['Differential']<=7) & (df["pass_type"] == "COMPLETE") ]
#Second plot
sns.kdeplot(qb.x_coord, qb.y_coord, ax=ax2, cmap='gist_heat', shade=True, shade_lowest=False, n_levels=10)

ax2.set_title("Andrew Luck")
ax2.set_xlabel('')
ax2.set_ylabel('')
ax2.set_xticks([])
ax2.set_yticks([])
ax2.set_xlim(-53.3333/2, 53.3333/2)
ax2.set_ylim(-15,60)
ax2.annotate( "Completion %: "+ str(luck_perc),(.5, -15) ,ha='center',fontsize=15)
for j in range(-15,60,1):
    ax2.annotate('--', (-3.1,j-0.5),
                 ha='center',fontsize =10)
    ax2.annotate('--', (3.1,j-0.5),
                 ha='center',fontsize =10)
    
for i in range(-10,60,5):
    ax2.axhline(i,c='w',ls='-',alpha=0.7, lw=1.5)
    
for i in range(-10,60,10):
    ax2.axhline(i,c='w',ls='-',alpha=1, lw=1.5)
    
for i in range(10,60-1,10):
    ax2.annotate(str(i), (-12.88,i-1.15),
            ha='center',fontsize =15,
                rotation=270)
    
    ax2.annotate(str(i), (12.88,i-0.65),
            ha='center',fontsize =15,
                rotation=90)

plt.show()
